# %% [markdown]
# # BREAKOUT ROOM ACTIVITY

# %% [markdown]
# # Group 3

# %% [markdown]
# ## Deepika Charley, Chinchu P, Sruthi S S

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data =pd.read_csv(r'C:\Users\sruth\OneDrive\Desktop\dsadatasets\hotel-tips.csv')

# %%
data.head()
# Out:
#    Unknown  bill_id  total_bill   tip     sex smoker  day    time  size
# 0      110    10111       16.99  1.01  Female     No  Sun  Dinner     2
# 1      111    10112       10.34  1.66    Male     No  Sun  Dinner     3
# 2      112    10113       21.01  3.50    Male     No  Sun  Dinner     3
# 3      113    10114       23.68  3.31    Male     No  Sun  Dinner     2
# 4      114    10115       24.59  3.61  Female     No  Sun  Dinner     4

# %%
data
# Out:
#      Unknown  bill_id  total_bill   tip     sex smoker   day    time  size
# 0        110    10111       16.99  1.01  Female     No   Sun  Dinner     2
# 1        111    10112       10.34  1.66    Male     No   Sun  Dinner     3
# 2        112    10113       21.01  3.50    Male     No   Sun  Dinner     3
# 3        113    10114       23.68  3.31    Male     No   Sun  Dinner     2
# 4        114    10115       24.59  3.61  Female     No   Sun  Dinner     4
# ..       ...      ...         ...   ...     ...    ...   ...     ...   ...
# 239      349    10350       29.03  5.92    Male     No   Sat  Dinner     3
# 240      350    10351       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241      351    10352       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      352    10353       17.82  1.75    Male     No   Sat  Dinner     2
# 243      353    10354       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 9 columns]

# %%
data.size
# Out:
# 2196

# %%
data.shape
# Out:
# (244, 9)

# %%
data.describe
# Out:
# <bound method NDFrame.describe of      Unknown  bill_id  total_bill   tip     sex smoker   day    time  size
# 0        110    10111       16.99  1.01  Female     No   Sun  Dinner     2
# 1        111    10112       10.34  1.66    Male     No   Sun  Dinner     3
# 2        112    10113       21.01  3.50    Male     No   Sun  Dinner     3
# 3        113    10114       23.68  3.31    Male     No   Sun  Dinner     2
# 4        114    10115       24.59  3.61  Female     No   Sun  Dinner     4
# ..       ...      ...         ...   ...     ...    ...   ...     ...   ...
# 239      349    10350       29.03  5.92    Male     No   Sat  Dinner     3
# 240      350    10351       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241      351    10352       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      352    10353       17.82  1.75    Male     No   Sat  Dinner     2
# 243      353    10354       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 9 columns]>

# %%
data.columns
# Out:
# Index(['Unknown', 'bill_id', 'total_bill', 'tip', 'sex', 'smoker', 'day',
#        'time', 'size'],
#       dtype='object')

# %%
missing_values=data.isna().sum()
print(missing_values)
# Out:
# Unknown       0
# bill_id       0
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
sns.countplot(x=data.sex) 
plt.show()

# %% [markdown]
# From the above bar graph it is evident that the bill payers  are mostly men than their female counterparts.

# %%
sns.countplot(x=data.time) 
plt.show()

# %% [markdown]
# More customers come for  dinner than lunch.

# %%
plt.bar(data['sex'],data['total_bill'])

plt.show()

# %% [markdown]
# Total bill paid by men is more than that of women.

# %%
plt.bar(data['sex'],data['tip'])
plt.xlabel("sex")
plt.ylabel("tip")
plt.show()

# %% [markdown]
# Among the bill payers, tip given by men are greater than women.

# %%
sns.countplot(x=data.day) 
plt.show()

# %% [markdown]
# More customers visit on saturdays compared to other days.

# %%
sns.barplot(x='day', y='total_bill', data=data, hue='sex')
plt.show()

# %% [markdown]
# eventhough customers are more on saturdays total bill is higher on sundays.

# %%
sns.countplot(x=data.smoker) 
plt.show()

# %% [markdown]
# The bill payers are mostly non smokers.

# %%
sns.countplot(x='size',data=data)
plt.show()

# %% [markdown]
# Most customers are 2 in number(group of 2 people). There is also a considerable count of customers arriving as a group of 3 or 4 people. Customers coming alone or as a group of 5 or 6 is very low.

# %%
sns.countplot(x='size',data=data)
plt.show()

# %% [markdown]
# Most customers are 2 in number(group of 2 people). There is also a considerable count of customers arriving as a group of 3 or 4 people. Customers coming alone or as a group of 5 or 6 is very low.

# %%
plt.bar(data['size'],data['total_bill'])

plt.show()

# %% [markdown]
# even if size 2 customers are more, total bill is greater for size 3. It is also noticeable that size 6 contributes a large amount although they are less in count.

# %%
plt.scatter(data['total_bill'], data['tip'])
plt.xlabel("total bill")
plt.ylabel("tip")
plt.show()

# %% [markdown]
# It is clear that the tip amount almost increses with the increase in total bill price.

# %%
sns.scatterplot(data['total_bill'], data['tip'], hue=data['sex'])
# Out:
# C:\Users\sruth\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# tip given by men is greater than women and tip also increases with total bill
