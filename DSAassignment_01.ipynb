# %% [markdown]
# # Assignment on Python for Data Science

# %% [markdown]
# 1. Read the dataset to python environment

# %%
import pandas as pd

# %%
data1 = pd.read_excel(r'C:\Users\sruth\OneDrive\Desktop\dsadatasets\iris.xls', sheet_name='Sheet1')  #read the dataset as data1

# %%
data1   #shows data1 table
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# 2. Display the columns in the dataset

# %%
data1.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %%
data1.columns    # Display the columns in Dataset
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# 3. Calculate the mean of each column of the dataset.

# %%
means = data1.mean()     #shows the mean of each columns
# Out:
# C:\Users\sruth\AppData\Local\Temp\ipykernel_5920\1245563222.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   means = data1.mean()

# %%
print(means)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12740\2585857840.py in <module>
# ----> 1 print(means)
#
# NameError: name 'means' is not defined

# %% [markdown]
# 4. Check for the null values present in the dataset.

# %%
data1.isna().sum()     # to find the null values
                       #here no null values found
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# 5. Perform meaningful visualizations using the dataset. Bring at least 3
# visualizations.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### BAR PLOT

# %%
plt.bar(data1['Classification'],data1['PL'])  # bar plot between Classifications and Pl
plt.show()

# %% [markdown]
# Iris_Virginica species has more petal length and Iris-sentosa has the least petal length

# %%
plt.bar(data1['Classification'],data1['PW'])
plt.show()

# %% [markdown]
# Iris-Virginica species has more petal width and Iris-sentosa has the least petal width

# %%
 plt.bar(data1['Classification'],data1['SL'])
plt.show()

# %% [markdown]
# Iris-Virginica species has more sepal length and Iris-sentosa has the least sepal length

# %%
plt.bar(data1['Classification'],data1['SW'])
plt.show()

# %% [markdown]
# Iris-sentosa species has more sepal width and Iris-versicolor has the least petal length

# %% [markdown]
# ### COUNTER PLOT

# %%
sns.countplot(x=data1.SW) 
plt.xlim(0, 10) 
plt.show()

# %% [markdown]
# count of sepal width SW is most in the number 3

# %%
sns.countplot(x=data1.PL)
plt.xlim(0, 10) 
plt.show()

# %%
sns.countplot(x=data1.PW)
plt.xlim(0, 10) 
plt.show()

# %% [markdown]
# counts in PW are more in 0.2

# %% [markdown]
# ### Scatter Plot

# %%
sns.scatterplot(data1['PL'], data1['SW'], hue=data1['Classification'])
# Out:
# C:\Users\sruth\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='PL', ylabel='SW'>

# %%
sns.scatterplot(data1['PL'], data1['PW'], hue=data1['Classification'])
# Out:
# C:\Users\sruth\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='PL', ylabel='PW'>

# %%
sns.scatterplot(data1['SL'], data1['SW'], hue=data1['Classification'])
# Out:
# C:\Users\sruth\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SL', ylabel='SW'>

# %%
sns.scatterplot(data1['SL'], data1['PW'], hue=data1['Classification'])
# Out:
# C:\Users\sruth\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SL', ylabel='PW'>
